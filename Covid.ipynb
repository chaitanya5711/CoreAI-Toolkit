# %%
import pandas as pd

# %%
df=pd.read_csv('Covid_data.csv')

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
#Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
df.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df.sum()
# Out:
# Date         4/29/20204/29/20204/29/20204/29/20204/29/20204...
# State        AlabamaAlaskaAlbertaAnguillaAnhuiArizonaArkans...
# Region       AfghanistanAlbaniaAlgeriaAndorraAngolaAntigua ...
# Confirmed                                              3193886
# Deaths                                                  227638
# Recovered                                               972719
# dtype: object

# %%
df.groupby('Region')[['Confirmed','Deaths','Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
#2 looking for the null values and replacing the null values

# %%
df.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as mt

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['State'] = df['State'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Date         0
# State        0
# Region       0
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Q. 2) Remove all the records where the Confirmed Cases is Less Than 10.

# %%
df.head(2)
# Out:
#         Date    State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Unkownn  Afghanistan       1939      60        252
# 1  4/29/2020  Unkownn      Albania        766      30        455

# %%
df['Confirmed'].sum()
# Out:
# np.int64(3193886)

# %%
f=df[df['Confirmed']>10]

# %%
f
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020   Unkownn     Afghanistan       1939      60        252
# 1    4/29/2020   Unkownn         Albania        766      30        455
# 2    4/29/2020   Unkownn         Algeria       3848     444       1702
# 3    4/29/2020   Unkownn         Andorra        743      42        423
# 4    4/29/2020   Unkownn          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [301 rows x 6 columns]

# %%
f['Confirmed'].sum()
# Out:
# np.int64(3193777)

# %%
#or

# %%
#permanent removing the values which are less than 10
df=df[~(df.Confirmed<10)]

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020   Unkownn     Afghanistan       1939      60        252
# 1    4/29/2020   Unkownn         Albania        766      30        455
# 2    4/29/2020   Unkownn         Algeria       3848     444       1702
# 3    4/29/2020   Unkownn         Andorra        743      42        423
# 4    4/29/2020   Unkownn          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
df.head(150)
# Out:
#           Date    State        Region  Confirmed  Deaths  Recovered
# 0    4/29/2020  Unkownn   Afghanistan       1939      60        252
# 1    4/29/2020  Unkownn       Albania        766      30        455
# 2    4/29/2020  Unkownn       Algeria       3848     444       1702
# 3    4/29/2020  Unkownn       Andorra        743      42        423
# 4    4/29/2020  Unkownn        Angola         27       2          7
# ..         ...      ...           ...        ...     ...        ...
# 150  4/29/2020  Unkownn  South Africa       5350     103       2073
# 151  4/29/2020  Unkownn   South Korea      10765     247       9059
# 152  4/29/2020  Unkownn   South Sudan         34       0          0
# 153  4/29/2020  Unkownn         Spain     236899   24275     132929
# 154  4/29/2020  Unkownn     Sri Lanka        649       7        136
#
# [150 rows x 6 columns]

# %%
# Q. 3) In which Region, maximum number of Confirmed cases were recorded ?

# %%
df.groupby('Region').Confirmed.sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# Venezuela              331
# Vietnam                270
# West Bank and Gaza     344
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 180, dtype: int64

# %%
#or
df.groupby('Region')['Confirmed'].sum().sort_values( ascending=False)
# Out:
# Region
# US            1039909
# Spain          236899
# Italy          203591
# France         166536
# UK             166432
#                ...
# Seychelles         11
# Burundi            11
# Suriname           10
# Gambia             10
# Holy See           10
# Name: Confirmed, Length: 180, dtype: int64

# %%
#Q. 4) In which Region, minimum number of Deaths cases were recorded ?

# %%
df.head(2)
# Out:
#         Date    State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Unkownn  Afghanistan       1939      60        252
# 1  4/29/2020  Unkownn      Albania        766      30        455

# %%
df.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# Equatorial Guinea                   1
# Eswatini                            1
# Cabo Verde                          1
# Maldives                            1
# Guinea-Bissau                       1
# Liechtenstein                       1
# Brunei                              1
# Burundi                             1
# Botswana                            1
# Suriname                            1
# Benin                               1
# Djibouti                            2
# Angola                              2
# Libya                               2
# Chad                                2
# West Bank and Gaza                  2
# Belize                              2
# Zambia                              3
# Malawi                              3
# Nicaragua                           3
# Syria                               3
# Ethiopia                            3
# Antigua and Barbuda                 3
# Gabon                               3
# Hong Kong                           4
# Zimbabwe                            4
# Name: Deaths, dtype: int64

# %%
#Q. 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
df.head(2)
# Out:
#         Date    State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2
# 182          0
# 186          0
# 187          0
# 195          0
# 199          0
# 200          0
# 202          0
# 204          0
# 205          0
# 208          0
# 213          0
# 216          0
# 219          0
# 224          0
# 231          0
# 232          0
# 233          0
# 235          0
# 240          0
# 241          0
# 243          0
# 245          0
# 248          0
# 249          0
# 251          0
# 252          0
# 253          0
# 254          0
# 255          0
# 257          0
# 258          0
# 261          0
# 262          0
# 263          0
# 265          0
# 268          0
# 269          0
# 270          0
# 274          0
# 275          0
# 277          0
# 278          0
# 280          0
# 287          0
# 298          0
# 299          0
# 302          0
# 303          0
# 307          0
# 308          0
# 310          0
# 311          0
# 312          0
# 313          0
# 315          0
# 316          0

# %%
#Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
df.head()
# Out:
#         Date    State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Unkownn  Afghanistan       1939      60        252
# 1  4/29/2020  Unkownn      Albania        766      30        455
# 2  4/29/2020  Unkownn      Algeria       3848     444       1702
# 3  4/29/2020  Unkownn      Andorra        743      42        423
# 4  4/29/2020  Unkownn       Angola         27       2          7

# %%
df['Confirmed'].sort_values(ascending=True)
# Out:
# 156        10
# 70         10
# 59         10
# 318        11
# 217        11
#         ...
# 57     165093
# 168    165221
# 80     203591
# 153    236899
# 265    299691
# Name: Confirmed, Length: 304, dtype: int64

# %%
df.sort_values(by=['Confirmed'], ascending=True).head(50)
# Out:
#           Date                         State  \
# 156  4/29/2020                       Unkownn
# 70   4/29/2020                       Unkownn
# 59   4/29/2020                       Unkownn
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 256  4/29/2020                    Montserrat
# 144  4/29/2020                       Unkownn
# 27   4/29/2020                       Unkownn
# 306  4/29/2020      Turks and Caicos Islands
# 118  4/29/2020                       Unkownn
# 215  4/29/2020                Grand Princess
# 206  4/29/2020   Falkland Islands (Malvinas)
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                       Unkownn
# 138  4/29/2020                       Unkownn
# 45   4/29/2020                       Unkownn
# 201  4/29/2020                       Curacao
# 114  4/29/2020                       Unkownn
# 137  4/29/2020                       Unkownn
# 260  4/29/2020                 New Caledonia
# 16   4/29/2020                       Unkownn
# 55   4/29/2020                       Unkownn
# 281  4/29/2020                       Qinghai
# 90   4/29/2020                       Unkownn
# 64   4/29/2020                       Unkownn
# 21   4/29/2020                       Unkownn
# 5    4/29/2020                       Unkownn
# 163  4/29/2020                       Unkownn
# 279  4/29/2020          Prince Edward Island
# 4    4/29/2020                       Unkownn
# 271  4/29/2020            Northern Territory
# 180  4/29/2020                       Unkownn
# 152  4/29/2020                       Unkownn
# 100  4/29/2020                       Unkownn
# 300  4/29/2020                     St Martin
# 110  4/29/2020                       Unkownn
# 51   4/29/2020                       Unkownn
# 159  4/29/2020                       Unkownn
# 244  4/29/2020                         Macau
# 204  4/29/2020  Diamond Princess cruise ship
# 31   4/29/2020                       Unkownn
# 32   4/29/2020                       Unkownn
# 310  4/29/2020                Virgin Islands
# 115  4/29/2020                       Unkownn
# 210  4/29/2020              French Polynesia
# 94   4/29/2020                       Unkownn
# 17   4/29/2020                       Unkownn
# 196  4/29/2020                Cayman Islands
# 296  4/29/2020                  Sint Maarten
# 267  4/29/2020                       Ningxia
#
#                                Region  Confirmed  Deaths  Recovered
# 156                          Suriname         10       1          8
# 70                           Holy See         10       0          2
# 59                             Gambia         10       1          8
# 318                            Canada         11       0          0
# 217                           Denmark         11       0         11
# 256                                UK         11       1          2
# 144                        Seychelles         11       0          6
# 27                            Burundi         11       1          4
# 306                                UK         12       1          5
# 118                         Nicaragua         13       3          7
# 215                            Canada         13       0          0
# 206                                UK         13       0         11
# 270                                US         14       2          0
# 136             Saint Kitts and Nevis         15       0          4
# 138  Saint Vincent and the Grenadines         16       0          8
# 45                           Dominica         16       0         13
# 201                       Netherlands         16       1         13
# 114                           Namibia         16       0          8
# 137                       Saint Lucia         17       0         15
# 260                            France         18       0         17
# 16                             Belize         18       2          9
# 55                               Fiji         18       0         12
# 281                    Mainland China         18       0         18
# 90                               Laos         19       0          7
# 64                            Grenada         20       0         13
# 21                           Botswana         23       1          5
# 5                 Antigua and Barbuda         24       3         11
# 163                       Timor-Leste         24       0          6
# 279                            Canada         27       0          0
# 4                              Angola         27       2          7
# 271                         Australia         28       0         25
# 180                          Zimbabwe         32       4          5
# 152                       South Sudan         34       0          0
# 100                            Malawi         36       3          7
# 300                            France         38       3         24
# 110                          Mongolia         38       0         10
# 51                            Eritrea         39       0         19
# 159                             Syria         43       3         21
# 244                             Macau         45       0         34
# 204                                US         49       0          0
# 31           Central African Republic         50       0         10
# 32                               Chad         52       2         19
# 310                                US         57       4          0
# 115                             Nepal         57       0         16
# 210                            France         58       0         50
# 94                              Libya         61       2         18
# 17                              Benin         64       1         33
# 196                                UK         73       1         10
# 296                       Netherlands         75      13         33
# 267                    Mainland China         75       0         75

# %%
#Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
df.head()
# Out:
#         Date    State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Unkownn  Afghanistan       1939      60        252
# 1  4/29/2020  Unkownn      Albania        766      30        455
# 2  4/29/2020  Unkownn      Algeria       3848     444       1702
# 3  4/29/2020  Unkownn      Andorra        743      42        423
# 4  4/29/2020  Unkownn       Angola         27       2          7

# %%
df.sort_values(by=['Recovered'] , ascending=False).head(10)
# Out:
#           Date    State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020  Unkownn           Spain     236899   24275     132929
# 61   4/29/2020  Unkownn         Germany     161539    6467     120400
# 76   4/29/2020  Unkownn            Iran      93657    5957      73791
# 80   4/29/2020  Unkownn           Italy     203591   27682      71252
# 229  4/29/2020    Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020  Unkownn          France     165093   24087      48228
# 167  4/29/2020  Unkownn          Turkey     117589    3081      44040
# 22   4/29/2020  Unkownn          Brazil      79685    5513      34132
# 158  4/29/2020  Unkownn     Switzerland      29407    1716      22600
# 78   4/29/2020  Unkownn         Ireland      20253    1190      13386
